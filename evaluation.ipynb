# %%
from pipeline import BreaKHisPipeline

# To allow auto reload to this notebook after modifying any external file imported
# %load_ext autoreload
# %autoreload 2

# %%
pipeline = BreaKHisPipeline()
pipeline.evaluate_and_plot_roc()
# Out:
# 2023-05-31 20:57:31.845 | INFO     | pipeline:__init__:43 - Class Initialized: {'n_epochs': 50, 'num_classes': 8, 'learning_rate': 0.001, 'batch_size': 32, 'data_split_train_ratio': 0.6, 'data_split_test_ratio': 0.4, 'image_size': (224, 224, 3), 'magnification': '40X'}
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Found 995 images belonging to 8 classes.
# Found 400 images belonging to 8 classes.
# Found 600 images belonging to 8 classes.
# 2023-05-31 20:57:36.471 | INFO     | helpers.focal_loss:__init__:8 - Class Initialized: {}
# 2023-05-31 20:57:36.506 | INFO     | pipeline:evaluate_and_plot_roc:141 - Evaluating the model.
# 2023-05-31 20:58:32.235 | INFO     | pipeline:evaluate_and_plot_roc:153 - Test Loss: 0.0168, Test Accuracy: 0.7150
# 2023-05-31 20:58:32.257 | INFO     | pipeline:evaluate_and_plot_roc:156 - Plotting the ROC curve.
# 19/19 [==============================] - 45s 2s/step
